# %% [markdown]
# <a href="https://colab.research.google.com/github/prinshu756/WineDetection/blob/main/MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


myDataset = pd.read_csv('/content/sample_data/california_housing_train.csv')
myDataset.head()
